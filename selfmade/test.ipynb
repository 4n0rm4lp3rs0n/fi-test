# %%
from nb201.nas_201_api import NASBench201API as API
# Create an API without the verbose log
# api = API('./nb201/NAS-Bench-201-v1_1-096897.pth', verbose=False)
api = API('./datas/NAS-Bench-201-v1_1-096897.pth')
print("api created")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7128\1598658779.py in <module>
# ----> 1 from nb201.nas_201_api import NASBench201API as API
#       2 # Create an API without the verbose log
#       3 # api = API('./nb201/NAS-Bench-201-v1_1-096897.pth', verbose=False)
#       4 api = API('./datas/NAS-Bench-201-v1_1-096897.pth')
#       5 print("api created")
#
# ModuleNotFoundError: No module named 'nb201'
